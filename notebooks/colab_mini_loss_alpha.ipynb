# %% [markdown]
# # Mini cribado Colab — pesos de pérdida × α_mix
#
# **3 entrenamientos** (uno por par de pesos) + **6 evaluaciones** (cada AE con α=0 y α=1).
#
# Punto fijo: `n=100`, `k=40` (**R=0.4**), `ρ=0` dB. No guarda checkpoints en Drive.
#
# Tiempo orientativo en GPU Colab: ~2–8 min total (no ~1 min × 6 redes).

# %%
# Ajusta la ruta si clonas el repo en otro sitio
import os, sys

ROOT = "/content/tfg-datos"
if os.path.isdir(ROOT):
    os.chdir(ROOT)
    sys.path.insert(0, ROOT)
else:
    print("Clona antes: !git clone <tu-repo> /content/tfg-datos")

from evaluation.chapter4.colab_mini_loss_alpha_check import run_mini_screening

results = run_mini_screening()
